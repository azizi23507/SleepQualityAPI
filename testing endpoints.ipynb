# %%
import requests

# %%
body = {
  "name": "Tom Barry",
    "age": 21,
    "email": "tom.barry@example.com"
}
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}

response = requests.post("http://localhost:8000/patients", json=body, headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'detail': "Email 'tom.barry@example.com' is already registered"}
# 409

# %%
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.get("http://localhost:8000/patients/1", headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'name': 'Tom Barry', 'age': 21, 'email': 'tom.barry@example.com', 'id': 1, 'created_at': '2026-08-22T17:43:55.783832'}
# 200

# %%
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.get("http://localhost:8000/patients", headers=header)
print(response.json())
print(response.status_code)
# Out:
# [{'name': 'Tom Barry', 'age': 21, 'email': 'tom.barry@example.com', 'id': 1, 'created_at': '2026-08-22T17:43:55.783832'}]
# 200

# %%
body = {
  "patient_id": 1,
  "sleep_duration_hours": 7.5,
  "heart_rate": 58.0,
  "is_deep_sleep": True,
  "raw_device_data": {"device": "fitbit-v3", "battery": 82}
}
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.post("http://localhost:8000/readings/", json=body, headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 6, 'record_at': '2026-08-21T23:06:41.732011'}
# 201

# %%
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.get("http://localhost:8000/patient/1/readings", headers=header)
print(response.json())
print(response.status_code)
# Out:
# [{'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 1, 'record_at': '2026-08-19T23:28:05.582819'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 2, 'record_at': '2026-08-19T23:28:52.946764'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 3, 'record_at': '2026-08-19T23:31:06.976142'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 4, 'record_at': '2026-08-19T23:34:58.884368'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 5, 'record_at': '2026-08-20T00:03:
# ...

# %%
response = requests.get("http://localhost:8000/readings", headers=header)
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
print(response.json())
print(response.status_code)
# Out:
# [{'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 77.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 2, 'record_at': '2026-08-19T23:28:52.946764'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 3, 'record_at': '2026-08-19T23:31:06.976142'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 4, 'record_at': '2026-08-19T23:34:58.884368'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 5, 'record_at': '2026-08-20T00:03:18.023477'}, {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 58.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 6, 'record_at': '2026-08-21T23:06:
# ...

# %%
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.get("http://localhost:8000/readings/2/prediction", headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'reading_id': 2, 'quality_score': 85.0, 'quality_label': 'good', 'model_version': 'rule-based-v0'}
# 200

# %%
response = requests.get("http://localhost:8000/health")
print(response.json())
print(response.status_code)
# Out:
# {'status': 'ok', 'database': 'connected'}
# 200

# %%
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.delete("http://localhost:8000/patients/12", headers=header)
print(response.status_code)
# Out:
# 404

# %%
body = {"age": 33}
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.patch("http://localhost:8000/patients/7", json=body, headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'name': 'Ben Fischer', 'age': 33, 'email': 'ben.fischer@example.com', 'id': 7, 'created_at': '2026-08-19T22:43:35.626739'}
# 200

# %%
body = {"heart_rate": 77}
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
response = requests.patch("http://localhost:8000/readings/2", json=body, headers=header)
print(response.json())
print(response.status_code)
# Out:
# {'patient_id': 1, 'sleep_duration_hours': 7.5, 'heart_rate': 77.0, 'is_deep_sleep': True, 'raw_device_data': {'device': 'fitbit-v3', 'battery': 82}, 'id': 2, 'record_at': '2026-08-19T23:28:52.946764'}
# 200

# %%
response = requests.delete("http://localhost:8000/readings/1", headers=header)
header = {"X-API-KEY": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}
print(response.status_code)
print(response.json())
# Out:
# 404
# {'detail': 'Reading with id 1 not found'}

# %%
import requests
headers = {"X-API-Key": "YAhavs_yJAlvdnd9q3HvzvnkO5xZnaMsnyMdjzgJ_F0"}

# create a patient in the containerized DB
requests.post("http://localhost:8000/patients",
              headers=headers,
              json={"name": "Anna Keller", "age": 34, "email": "anna@example.com"}).json()

# read it back
requests.get("http://localhost:8000/patients", headers=headers).json()
# Out:
# [{'name': 'Tom Barry',
#   'age': 21,
#   'email': 'tom.barry@example.com',
#   'id': 1,
#   'created_at': '2026-08-22T17:43:55.783832'},
#  {'name': 'Anna Keller',
#   'age': 34,
#   'email': 'anna@example.com',
#   'id': 2,
#   'created_at': '2026-08-22T18:03:55.129187'}]
